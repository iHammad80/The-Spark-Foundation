# %% [markdown]
# # Decision Tree

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
df_modified = pd.read_csv('Iris.csv')
df_modified
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
input1 = df_modified.drop(['Species'], axis = 1)
target = df_modified['Species']

# %%
model = DecisionTreeClassifier()
model.fit(input1, target)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# #### Plotting Tree

# %%
tree.plot_tree(model)
# Out:
# [Text(0.4, 0.8333333333333334, 'X[0] <= 50.5\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(0.6, 0.5, 'X[0] <= 100.5\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 50\nvalue = [0, 50, 0]'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 50\nvalue = [0, 0, 50]')]

# %% [markdown]
# #### More clear Visuals

# %%
feature = ['Sepal length (cm)', 'Sepal width (cm)','Petal length (cm)', 'Petal width (cm)']
Classes = ['Setosa', 'Versicolor', 'Verginica']
fig, axes = plt.subplots(nrows=1, ncols=1, figsize = (4,4),dpi = 300)

tree.plot_tree(model, feature_names=feature, class_names=Classes, filled=True)
# Out:
# [Text(0.4, 0.8333333333333334, 'Sepal length (cm) <= 50.5\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]\nclass = Setosa'),
#  Text(0.2, 0.5, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]\nclass = Setosa'),
#  Text(0.6, 0.5, 'Sepal length (cm) <= 100.5\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]\nclass = Versicolor'),
#  Text(0.4, 0.16666666666666666, 'gini = 0.0\nsamples = 50\nvalue = [0, 50, 0]\nclass = Versicolor'),
#  Text(0.8, 0.16666666666666666, 'gini = 0.0\nsamples = 50\nvalue = [0, 0, 50]\nclass = Verginica')]
